# %%
import holoviews as hv
import panel as pn
from holoviews import opts, streams
from spectraclass.widgets.polydraw import RegionSelector

hv.extension('bokeh')
#hv.help(hv.Polygons)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
# ...

# %%
selector = RegionSelector()
selector.panel()
# Out:
#  poly(split)= None
#  get_selection.selected_regions = []
#  poly(split)= {'x': array([0.24369748, 0.65966387, 0.40756303, 0.24369748]), 'y': array([0.73469388, 0.73877551, 0.34285714, 0.73469388]), 'fill_color': 'green', 'geom_type': 'Polygon'}</br>
#  get_selection.selected_regions = [{'x': array([0.24369748, 0.65966387, 0.40756303, 0.24369748]), 'y': array([0.73469388, 0.73877551, 0.34285714, 0.73469388]), 'fill_color': 'green', 'geom_type': 'Polygon'}]</br>
#  poly(split)= {'x': array([0.4789916 , 0.70168067, 0.76470588, 0.4789916 ]), 'y': array([0.17142857, 0.46530612, 0.14693878, 0.17142857]), 'fill_color': 'green', 'geom_type': 'Polygon'}</br>
# ...
