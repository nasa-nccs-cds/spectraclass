# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from spectraclass.data.base import DataManager
import xarray as xa
from spectraclass.xext.xgeo import XGeo
from spectraclass.data.spatial.manager import SpatialDataManager
from spectraclass.gui.spatial.basemap import TileServiceBasemap

# %%
dm: DataManager = DataManager.initialize( "demo2", 'desis' )
tile_raster: xa.DataArray = DataManager.instance().modal.readSpectralData()
[x0,x1,y0,y1] = SpatialDataManager.extent( tile_raster )
# Out:
# Using config file: '/Users/tpmaxwel/.spectraclass/config/desis/demo2.py'
# Opening log file:  '/Users/tpmaxwel/.spectraclass/logging/desis/demo2.log'
# Reading raster file /Users/tpmaxwel/Development/Data/DESIS/DESIS-HSI-L1C-DT0468853252_002-20200628T153803-V0210-SPECTRAL_IMAGE.tif, dims = ('band', 'y', 'x'), shape = (235, 1743, 1547)

# %%
iband = 100
alpha = 0.5
vrange = [ 1000, 5000 ]

base = TileServiceBasemap()
base.setup_plot( (x0 ,x1), (y0 ,y1), standalone=True )
raster_layer = tile_raster[iband].squeeze( drop=True )
raster_layer.plot.imshow( ax=base.gax, alpha=alpha, vmin=vrange[0], vmax=vrange[1], cmap="jet" )
plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
