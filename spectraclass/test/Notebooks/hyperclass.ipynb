# %%
# %matplotlib widget
from spectraclass.data.base import DataManager
from spectraclass.gui.spatial.application import Spectraclass
from spectraclass.model.labels import LabelsManager
import xarray as xa


dm: DataManager = DataManager.initialize("demo1",'desis')
app = Spectraclass.instance()
project_data: xa.Dataset = dm.loadCurrentProject("main")
print(f"Loaded project data: vars = {project_data.variables.keys()}")

classes = [ ('Class-1', "cyan"),
            ('Class-2', "green"),
            ('Class-3', "magenta"),
            ('Class-4', "blue")]
LabelsManager.instance().setLabels( classes )

app.gui()

# %%
# Out:
# Configuration error: '/Users/tpmaxwel/.hyperclass/aviris.py' is not a file.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#  DataManager: loadCurrentProject: graph
# Load dataset NONE, current datasets = dict_keys([])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/tpmaxwel/Development/Cache/spectraclass/swift/NONE.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7df705b39a1d> in <module>
#       6
#       7 app: Spectraclass = Spectraclass.instance()
# ----> 8 app.gui( False )
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/gui/spatial/application.py in gui(self, embed)
#      71
#      72         map = mapManager.gui()
# ---> 73         graph = graphManager.gui()
#      74         points = pointCloudManager.instance().gui()
#      75         actionsPanel = ActionsPanel.instance().gui()
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/gui/graph.py in gui(self, **kwargs)
#     119     def gui(self, **kwargs ) -> ipw.Tab():
#     120         if self._wGui is None:
# --> 121             self._wGui = self._createGui( **kwargs )
#     122         return self._wGui
#     123
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/gui/graph.py in _createGui(self, **kwargs)
#     139         wTab = ipw.Tab( layout = ip.Layout( width='auto', flex='0 0 330px' ) )
#     140         for iG in range(self._ngraphs):
# --> 141             self._graphs.append( JbkGraph( **kwargs ) )
#     142             wTab.set_title(iG, str(iG))
#     143         wTab.children = [ g.gui() for g in self._graphs ]
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/gui/graph.py in __init__(self, **kwargs)
#      20
#      21     def __init__( self, **kwargs ):
# ---> 22         self.init_data(**kwargs)
#      23         self._selected_pids: List[int] = [0]
#      24         self._source = ColumnDataSource(data=dict(
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/gui/graph.py in init_data(cls, **kwargs)
#      47     def init_data(cls, **kwargs ):
#      48         if cls._x is None:
# ---> 49             project_data: xa.Dataset = DataManager.instance().loadCurrentProject("graph")
#      50             cls._x: np.ndarray = project_data["plot-x"].values
#      51             cls._ploty: np.ndarray = project_data["plot-y"].values
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/data/manager.py in loadCurrentProject(self, caller_id)
#      85     def loadCurrentProject(self, caller_id: str ) -> xa.Dataset:
#      86         print( f" DataManager: loadCurrentProject: {caller_id}" )
# ---> 87         return self.mode_data_manager.loadCurrentProject()
#      88
#      89 class ModeDataManager( tlc.Configurable, AstroModeConfigurable ):
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/data/manager.py in loadCurrentProject(self)
#     279
#     280     def loadCurrentProject(self) -> xa.Dataset:
# --> 281         return self.loadDataset( self.dm.dataset )
#     282
#     283     @property
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/spectraclass-0.1-py3.7.egg/spectraclass/data/manager.py in loadDataset(self, dsid, *args, **kwargs)
#     262         if dsid not in self.datasets:
#     263             data_file = os.path.join( self.datasetDir, dsid + ".nc" )
# --> 264             dataset: xa.Dataset = xa.open_dataset( data_file )
#     265             print( f" ---> Opened Dataset {dsid} from file {data_file}")
#     266             vshapes = [ f"{vname}{dataset.variables[vname].shape}" for vname in dataset.variables.keys() ]
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     570
#     571         opener = _get_backend_cls(engine)
# --> 572         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     573
#     574     with close_on_error(store):
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     362             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     363         )
# --> 364         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     365
#     366     def _acquire(self, needs_lock=True):
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     312         self._group = group
#     313         self._mode = mode
# --> 314         self.format = self.ds.data_model
#     315         self._filename = self.ds.filepath()
#     316         self.is_remote = is_remote_uri(self._filename)
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     371     @property
#     372     def ds(self):
# --> 373         return self._acquire()
#     374
#     375     def open_store_variable(self, name, var):
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     365
#     366     def _acquire(self, needs_lock=True):
# --> 367         with self._manager.acquire_context(needs_lock) as root:
#     368             ds = _nc4_require_group(root, self._group, self._mode)
#     369         return ds
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/opt/anaconda3/envs/spectraclass/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/Users/tpmaxwel/Development/Cache/spectraclass/swift/NONE.nc'
