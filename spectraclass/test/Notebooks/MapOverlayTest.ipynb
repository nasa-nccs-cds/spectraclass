# %%
# %matplotlib widget
import xarray as xa
from spectraclass.data.base import DataManager
from spectraclass.model.labels import LabelsManager, lm
from spectraclass.gui.spatial.map import MapManager, mm
import numpy as np
import matplotlib.pyplot as plt

# %%
dm: DataManager = DataManager.initialize("demo2", 'desis')
dm.loadCurrentProject("main")
classes = [('Class-1', "cyan"), ('Class-2', "green"), ('Class-3', "magenta"), ('Class-4', "blue")]
lm().setLabels(classes)
# Out:
# Using config file: '/Users/tpmaxwel/.spectraclass/config/desis/demo2.py'
# Opening log file:  '/Users/tpmaxwel/.spectraclass/logging/desis/demo2.log'
# Loading metadata from file: /Users/tpmaxwel/Development/Data/DESIS/DESIS-HSI-L1C-DT0468853252_002-20200628T153803-V0210.mdata.txt

# %%
mm().gui(basemap=False)
# Out:
# /Applications/anaconda3/envs/mpl_spectraclass/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Applications/anaconda3/envs/mpl_spectraclass/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Applications/anaconda3/envs/mpl_spectraclass/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /Applications/anaconda3/envs/mpl_spectraclass/lib/python3.9/site-packages/cartopy/io/ogc_clients.py:165: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in polys:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…
