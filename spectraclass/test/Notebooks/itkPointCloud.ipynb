# %%
import numpy as np
from spectraclass.data.manager import DataManager
from spectraclass.gui.points import PointCloudManager
from itkwidgets import view
import xarray as xa

config = dict(
    reduce = dict( method="Autoencoder", dims=16, subsample=5 ),
    data = dict( cache="~/Development/Cache" ),
    umap = dict( dims=3, nepochs=100, alpha=0.25, nneighbors=8 ),

)
DataManager.instance().initProject( 'swiftclass', 'pointCloud_test', config )

PointCloudManager.instance().gui()
# Out:
# Using TensorFlow backend.
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/tpmaxwel/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Opened Dataset Autoencoder-16-ss5 from file ~/Development/Cache/swiftclass/Autoencoder-16-ss5.nc
# Get Activation flow for dsid swift
# Tue Sep 29 17:54:51 2020 Building RP forest with 16 trees
# Tue Sep 29 17:54:52 2020 NN descent for 30 iterations
# 	 1  /  30
# 	 2  /  30
# 	 3  /  30
# 	Stopping threshold met -- exiting after 3 iterations
# Computed NN Graph with 8 neighbors and 44447 verts in 20.87824511528015 sec (0.34797075192133586 min)
# Completed data prep in 1.1920928955078125e-06 sec, Now fitting umap[3] with 44447 samples and 0 labels
# Running umap[3] with init random, input shape = (44447, 16), #epochs = 50
# Computing umap embedding with nepochs = 100, alpha = 0.25, nLabels = 0
#  >>> Embed n_epochs=100, alpha=0.25
# Completed simplicial_set_embedding, times = 0.0008460680643717448 0.1098904808362325 min
# Completed umap fitting in 0.17736058235168456 min, embedding shape = (44447, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0d4d277d8ef8> in <module>
#      14 dataManager.initProject( 'swiftclass', 'pointCloud_test', config )
#      15
# ---> 16 pointCloudManager.gui()
#      17
#
# ~/Development/Projects/spectraclass/spectraclass/gui/points.py in gui(self, **kwargs)
#      52         if self._gui is None:
#      53             self.init_data()
# ---> 54             self._gui = view( point_sets = [ self._embedding.values, self._marker_points ], point_set_sizes=[1,10] )
#      55             self._gui.layout = { 'width': '100%', 'height': '100%', 'max_height': "2000px", 'max_width': "2000px" }
#      56         return self._gui
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/itkwidgets/widget_viewer.py in view(image, label_image, label_image_names, label_image_weights, label_image_blend, cmap, lut, select_roi, interpolation, gradient_opacity, opacity_gaussians, channels, slicing_planes, shadow, blend_mode, point_sets, point_set_colors, point_set_opacities, point_set_representations, point_set_sizes, geometries, geometry_colors, geometry_opacities, ui_collapsed, rotate, annotations, axes, mode, **kwargs)
#    1084                     rotate=rotate, ui_collapsed=ui_collapsed,
#    1085                     annotations=annotations, axes=axes, mode=mode,
# -> 1086                     **kwargs)
#    1087     return viewer
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/itkwidgets/widget_viewer.py in __init__(self, **kwargs)
#     374             kwargs['interpolation'] = False
#     375
# --> 376         super(Viewer, self).__init__(**kwargs)
#     377
#     378         if not self.image and not self.label_image:
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
# --> 415         self.open()
#     416
#     417     def __del__(self):
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in open(self)
#     426         """Open a comm to the frontend if one isn't already open."""
#     427         if self.comm is None:
# --> 428             state, buffer_paths, buffers = _remove_buffers(self.get_state())
#     429
#     430             args = dict(target_name='jupyter.widget',
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in get_state(self, key, drop_defaults)
#     516         for k in keys:
#     517             to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
# --> 518             value = to_json(getattr(self, k), self)
#     519             if not PY3 and isinstance(traits[k], Bytes) and isinstance(value, bytes):
#     520                 value = memoryview(value)
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/itkwidgets/trait_types.py in polydata_list_to_json(polydata_list, manager)
#     385         return None
#     386     else:
# --> 387         compressor = zstd.ZstdCompressor(level=3)
#     388
#     389         json = []
#
# ~/opt/anaconda3/envs/spectraclass_itk/lib/python3.7/site-packages/itkwidgets/trait_types.py in polydata_list_to_json(polydata_list, manager)
#     385         return None
#     386     else:
# --> 387         compressor = zstd.ZstdCompressor(level=3)
#     388
#     389         json = []
#
# _pydevd_bundle/pydevd_cython_darwin_37_64.pyx in _pydevd_bundle.pydevd_cython_darwin_37_64.ThreadTracer.__call__()
#
# _pydevd_bundle/pydevd_cython_darwin_37_64.pyx in _pydevd_bundle.pydevd_cython_darwin_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython_darwin_37_64.pyx in _pydevd_bundle.pydevd_cython_darwin_37_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython_darwin_37_64.pyx in _pydevd_bundle.pydevd_cython_darwin_37_64.PyDBFrame.do_wait_suspend()
#
# /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1110
#    1111         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1112             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1113
#    1114     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1125
#    1126                 self.process_internal_commands()
# -> 1127                 time.sleep(0.01)
#    1128
#    1129         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:
